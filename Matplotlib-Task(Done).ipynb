# %% [markdown]
# # <a href="https://colab.research.google.com/drive/1XA4A17zH7sGDlGgBIcICtcn4Jz7viC0k?usp=sharing">Click Here</a> to open this file on Google Colab

# %% [markdown]
# # Data Visualization with Matplotlib

# %% [markdown]
# RUN THE CELL BELOW AND START SOLVING

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# Plot (x,y) axes and set the labels and titles <br>
# Use ax.plot function to plot a simple sinusoid to match the plot below <br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
x = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x,np.sin(x),'-')
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.show()

# %% [markdown]
# # Given :

# %% [markdown]
# Use Scatter Plots to draw below as the given output <br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
y = np.linspace(0, 10, 30)
z = np.sin(x)
plt.plot(y, z, 'o', color='black');

# %% [markdown]
# # Given :

# %% [markdown]
# use line and color codes to plot points along with a line connecting them<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
plt.plot(y, z, '-ok');   # Here '-' means Line & 'o' means circle marker & 'k' means black ('-ok')

# %% [markdown]
# # Given :

# %% [markdown]
# create a single figure with multiple lines as follows<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %% [markdown]
# # Given :

# %% [markdown]
# Create the plot given below in the output by using 'linestyle'  keyword.<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
plt.plot(x, x + 0, linestyle='-')#Here '-' for solid similarly
plt.plot(x, x + 1, linestyle='--')#dashed
plt.plot(x, x + 2, linestyle='-.')#dashdot
plt.plot(x, x + 3, linestyle=':')#dotted
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':') # dotted

# %% [markdown]
# # Given :

# %% [markdown]
# use 'linestyle' and 'color' keyword  to draw as given below in the output<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
plt.plot(x, x + 0, '-g')  # Here '-g' for solid green similarly
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# # Given :

# %% [markdown]
# # Submitted By : <a href="https://www.linkedin.com/in/saurabh-satapathy-692a6a1b9">Saurabh Satapathy</a>

# %% [markdown]
# # GOOD JOB!!
